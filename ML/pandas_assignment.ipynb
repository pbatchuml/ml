# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({'From_To': ['LoNDon_paris', 'MAdrid_miLAN',
'londON_StockhOlm',
'Budapest_PaRis', 'Brussels_londOn'],
'FlightNumber': [10045, np.nan, 10065, np.nan, 10085],
'RecentDelays': [[23, 47], [], [24, 43, 87], [13], [67, 32]],
'Airline': ['KLM(!)', '<Air France> (12)', '(British Airways. )',
'12. Air France', '"Swiss Air"']})

# %%
df.head()
# Out:
#             From_To  FlightNumber  RecentDelays              Airline
# 0      LoNDon_paris       10045.0      [23, 47]               KLM(!)
# 1      MAdrid_miLAN           NaN            []    <Air France> (12)
# 2  londON_StockhOlm       10065.0  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis           NaN          [13]       12. Air France
# 4   Brussels_londOn       10085.0      [67, 32]          "Swiss Air"

# %%
df['FlightNumber'].fillna( method ='ffill', limit = 1, inplace = True) 
df
# Out:
#             From_To  FlightNumber  RecentDelays              Airline
# 0      LoNDon_paris       10045.0      [23, 47]               KLM(!)
# 1      MAdrid_miLAN       10045.0            []    <Air France> (12)
# 2  londON_StockhOlm       10065.0  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis       10065.0          [13]       12. Air France
# 4   Brussels_londOn       10085.0      [67, 32]          "Swiss Air"

# %%
df['FlightNumber'] = df['FlightNumber'].astype(int)

# %%
df[['FROM','TO']] = df.From_To.str.split("_",expand=True,)
df
# Out:
#             From_To  FlightNumber  RecentDelays              Airline  \
# 0      LoNDon_paris         10045      [23, 47]               KLM(!)
# 1      MAdrid_miLAN         10045            []    <Air France> (12)
# 2  londON_StockhOlm         10065  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis         10065          [13]       12. Air France
# 4   Brussels_londOn         10085      [67, 32]          "Swiss Air"
#
#        FROM         TO
# 0    LoNDon      paris
# 1    MAdrid      miLAN
# 2    londON  StockhOlm
# 3  Budapest      PaRis
# 4  Brussels     londOn

# %%
df['FROM'] = df['FROM'].str.title()
df['TO'] = df['TO'].str.title()

# %%
df
# Out:
#             From_To  FlightNumber  RecentDelays              Airline  \
# 0      LoNDon_paris         10045      [23, 47]               KLM(!)
# 1      MAdrid_miLAN         10045            []    <Air France> (12)
# 2  londON_StockhOlm         10065  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis         10065          [13]       12. Air France
# 4   Brussels_londOn         10085      [67, 32]          "Swiss Air"
#
#        FROM         TO
# 0    London      Paris
# 1    Madrid      Milan
# 2    London  Stockholm
# 3  Budapest      Paris
# 4  Brussels     London

# %%
df.RecentDelays
# Out:
# 0        [23, 47]
# 1              []
# 2    [24, 43, 87]
# 3            [13]
# 4        [67, 32]
# Name: RecentDelays, dtype: object

# %%
df1=pd.DataFrame(df.RecentDelays.tolist(), index= df.index)

# %%
df1
# Out:
#       0     1     2
# 0  23.0  47.0   NaN
# 1   NaN   NaN   NaN
# 2  24.0  43.0  87.0
# 3  13.0   NaN   NaN
# 4  67.0  32.0   NaN

# %%
cols = ['delay1','delay2','delay3']

# %%
df1.columns = cols
df1
# Out:
#    delay1  delay2  delay3
# 0    23.0    47.0     NaN
# 1     NaN     NaN     NaN
# 2    24.0    43.0    87.0
# 3    13.0     NaN     NaN
# 4    67.0    32.0     NaN

# %%
df['delay1'] = df1['delay1']
df['delay2'] = df1['delay2']
df['delay3'] = df1['delay3']

# %%
df
# Out:
#             From_To  FlightNumber  RecentDelays              Airline  \
# 0      LoNDon_paris         10045      [23, 47]               KLM(!)
# 1      MAdrid_miLAN         10045            []    <Air France> (12)
# 2  londON_StockhOlm         10065  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis         10065          [13]       12. Air France
# 4   Brussels_londOn         10085      [67, 32]          "Swiss Air"
#
#        FROM         TO  delay1  delay2  delay3
# 0    London      Paris    23.0    47.0     NaN
# 1    Madrid      Milan     NaN     NaN     NaN
# 2    London  Stockholm    24.0    43.0    87.0
# 3  Budapest      Paris    13.0     NaN     NaN
# 4  Brussels     London    67.0    32.0     NaN

# %%
df.fillna(0)
# Out:
#             From_To  FlightNumber  RecentDelays              Airline  \
# 0      LoNDon_paris         10045      [23, 47]               KLM(!)
# 1      MAdrid_miLAN         10045            []    <Air France> (12)
# 2  londON_StockhOlm         10065  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis         10065          [13]       12. Air France
# 4   Brussels_londOn         10085      [67, 32]          "Swiss Air"
#
#        FROM         TO  delay1  delay2  delay3
# 0    London      Paris    23.0    47.0     0.0
# 1    Madrid      Milan     0.0     0.0     0.0
# 2    London  Stockholm    24.0    43.0    87.0
# 3  Budapest      Paris    13.0     0.0     0.0
# 4  Brussels     London    67.0    32.0     0.0

# %%
df.drop(['From_To','RecentDelays'],axis=1, inplace=True)

# %%
df
# Out:
#    FlightNumber              Airline      FROM         TO  delay1  delay2  \
# 0         10045               KLM(!)    London      Paris    23.0    47.0
# 1         10045    <Air France> (12)    Madrid      Milan     NaN     NaN
# 2         10065  (British Airways. )    London  Stockholm    24.0    43.0
# 3         10065       12. Air France  Budapest      Paris    13.0     NaN
# 4         10085          "Swiss Air"  Brussels     London    67.0    32.0
#
#    delay3
# 0     NaN
# 1     NaN
# 2    87.0
# 3     NaN
# 4     NaN

# %%
#df['Airline'].replace(regex=True, inplace=True, to_replace=r'[^a-z0-9.\-()!<>]', value=r'')
df["Airline"]=df["Airline"].str.replace(r"[^a-zA-Z ]+", "").str.strip()

# %%
df
# Out:
#    FlightNumber          Airline      FROM         TO  delay1  delay2  delay3
# 0         10045              KLM    London      Paris    23.0    47.0     NaN
# 1         10045       Air France    Madrid      Milan     NaN     NaN     NaN
# 2         10065  British Airways    London  Stockholm    24.0    43.0    87.0
# 3         10065       Air France  Budapest      Paris    13.0     NaN     NaN
# 4         10085        Swiss Air  Brussels     London    67.0    32.0     NaN

# %%
df =df.fillna(0)

# %%
df
# Out:
#    FlightNumber          Airline      FROM         TO  delay1  delay2  delay3
# 0         10045              KLM    London      Paris    23.0    47.0     0.0
# 1         10045       Air France    Madrid      Milan     0.0     0.0     0.0
# 2         10065  British Airways    London  Stockholm    24.0    43.0    87.0
# 3         10065       Air France  Budapest      Paris    13.0     0.0     0.0
# 4         10085        Swiss Air  Brussels     London    67.0    32.0     0.0

# %%
df['delay1'] = df['delay1'].astype(int)
df['delay2'] = df['delay2'].astype(int)
df['delay3'] = df['delay3'].astype(int)

# %%
df
# Out:
#    FlightNumber          Airline      FROM         TO  delay1  delay2  delay3
# 0         10045              KLM    London      Paris      23      47       0
# 1         10045       Air France    Madrid      Milan       0       0       0
# 2         10065  British Airways    London  Stockholm      24      43      87
# 3         10065       Air France  Budapest      Paris      13       0       0
# 4         10085        Swiss Air  Brussels     London      67      32       0
